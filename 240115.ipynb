# %% [markdown]
# <a href="https://colab.research.google.com/github/jaehun5708/aipython/blob/main/240115.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
regr = linear_model.LinearRegression()
X = [[164], [179], [162], [170]]
y = [53, 63, 55, 59]
regr.fit(X, y)
plt.scatter(X, y)
y_pred = regr.predict(X)
plt.plot(X, y_pred, color = 'blue', linewidth = 3)
plt.show()
# import numpy as np: NumPy 라이브러리를 가져와서 np로 별칭을 붙입니다. NumPy는 다차원 배열과 행렬 연산을 위한 파이썬 라이브러리입니다.

# from sklearn import linear_model: scikit-learn 라이브러리에서 선형 회귀 모델을 가져옵니다.

# import matplotlib.pyplot as plt: Matplotlib 라이브러리에서 pyplot 모듈을 가져와서 시각화를 위해 사용합니다.

# regr = linear_model.LinearRegression(): 선형 회귀 모델을 생성합니다. regr이라는 변수에 모델을 할당합니다.

# X = [[164], [179], [162], [170]]: 독립 변수(입력 데이터)를 나타내는 리스트입니다. 각 키 값은 특정 개체의 특징(이 예제에서는 키)를 나타냅니다.

# y = [53, 63, 55, 59]: 종속 변수(타겟 데이터 또는 출력)를 나타내는 리스트입니다. 각 값은 해당 개체의 종속 변수(이 예제에서는 몸무게)를 나타냅니다.

# regr.fit(X, y): 선형 회귀 모델을 입력 데이터 X와 대상 데이터 y에 대해 훈련합니다.

# plt.scatter(X, y): 입력 데이터와 대상 데이터를 산점도로 표시합니다.

# y_pred = regr.predict(X): 훈련된 선형 회귀 모델을 사용하여 입력 데이터에 대한 예측값을 생성합니다.

# plt.plot(X, y_pred, color='blue', linewidth=3): 예측값을 선으로 표시하여 선형 회귀 모델을 시각화합니다. 파란색 선이 그려지고, 선의 두께는 3입니다.

# plt.show(): 시각화된 그래프를 표시합니다.

# %%
input_data = [[180], [185]] #새로 예측해 볼 데이터
result = regr.predict(input_data)
print(result)
# Out:
# [63.71244635 66.47353362]

# %%
# 재배 면적과 수확량
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
regr = linear_model.LinearRegression()
X = np.array([[2.1], [10], [3], [1],[3.5],[5],[8]])
y = np.array([64.9, 292.6, 85.9, 30.92, 110.5, 163.4, 163.4])
regr.fit(X, y)
plt.scatter(X, y)
y_pred = regr.predict(X)
plt.plot(X, y_pred, color = 'blue', linewidth = 3)
plt.show()
result = regr.predict([[7], [12]])
print(result)
# Out:
# [189.55106566 316.14785212]

# %%
# 부모의 키 데이터를 측정하여 자녀의 키가 속하는 그룹을 예측
from sklearn import tree
parents_height = [[180,165],[175,160],[180,172],[165,160],[171,152]]
child_height = [3,2,2,1,1]
dt_model = tree.DecisionTreeClassifier()
dt_model.fit(parents_height, child_height)
dt_pred=dt_model.predict([[175,153]])
dt_pred
# Out:
# array([2])

# %%
# 데이터 불러오기
import pandas as pd
std=pd.read_csv("/content/Student_Marks.csv")
std
# Out:
#     number_courses  time_study   Marks
# 0                3       4.508  19.202
# 1                4       0.096   7.734
# 2                4       3.133  13.811
# 3                6       7.909  53.018
# 4                8       7.811  55.299
# ..             ...         ...     ...
# 95               6       3.561  19.128
# 96               3       0.301   5.609
# 97               4       7.163  41.444
# 98               7       0.309  12.027
# 99               3       6.335  32.357
#
# [100 rows x 3 columns]

# %%
# 데이터 탐색 및 전처리
std.describe()
# Out:
#        number_courses  time_study       Marks
# count      100.000000  100.000000  100.000000
# mean         5.290000    4.077140   24.417690
# std          1.799523    2.372914   14.326199
# min          3.000000    0.096000    5.609000
# 25%          4.000000    2.058500   12.633000
# 50%          5.000000    4.022000   20.059500
# 75%          7.000000    6.179250   36.676250
# max          8.000000    7.957000   55.299000

# %%
# 데이터 탐색 및 전처리
std.info()
#head,tail
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   number_courses  100 non-null    int64
#  1   time_study      100 non-null    float64
#  2   Marks           100 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
#각 속성 간의 상관관계
std.corr()
# Out:
#                 number_courses  time_study     Marks
# number_courses        1.000000    0.204844  0.417335
# time_study            0.204844    1.000000  0.942254
# Marks                 0.417335    0.942254  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax=plt.subplots(ncols=2, figsize=(12,6))
sns.scatterplot(data=std, x='number_courses',y='Marks', ax=ax[0])
sns.scatterplot(data=std, x='time_study',y='Marks', ax=ax[1])
plt.show()

# %%
#  데이터 탐색 및 전처리
# train_test_split 함수를 사용하여 데이터 셋을 훈련(train) 셋과 테스트(test) 셋로 분할
from sklearn.model_selection import train_test_split
x=std.drop('Marks',axis=1)
y=std['Marks']
X_train, X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2,random_state=42)#0.2는 테스트 할 20%, 80%는 훈련

# %%
#  모델 생성 및 학습하기
#  선형회귀 알고리즘 모델 생성
from sklearn.linear_model import LinearRegression
lr_model=LinearRegression()
# 학습하기
lr_model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
# 모델 평가 및 예측하기
# ▪ 모델 평가 지표 구하기
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
# 모델 평가하기
lr_pred=lr_model.predict(X_test)
# 성능 평가 지표
print(r2_score(lr_pred, Y_test)) # 0~1사이 1에 가까울수록 좋
print(mean_squared_error(lr_pred,Y_test))# 상대적으로 숫자가 낮을수록 좋
# Out:
# 0.9219617777759717
# 14.200726136374552

# %%
#시각화
#시험 점수와 공부시간의 관계를 회귀선으로 표현
import matplotlib.pyplot as plt
import seaborn as sns
sns.regplot(x=std['time_study'],y=std['Marks'])
plt.show()
